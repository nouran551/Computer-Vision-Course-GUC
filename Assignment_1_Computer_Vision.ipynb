# %%
import cv2   #to import the library of openCv in order to use its pre-defined functions.
from matplotlib import pyplot as plt   #used for the image display function demonstrated later.

# %%
def displayImages(imgs):
  r = len(imgs) //2
  if len(imgs) % 2 != 0:
    r+=1
  plt.subplot(nrows=r,ncols=2,figsize=(20,20))
  for i in range (0, len(imgs)):
    plt.subplot(r,2,i+1)
    plt.imshow(imgs[i],cmap = 'gray')

# %%
from PIL import Image

img1 = Image.open('/content/Input1.png')
img2 = Image.open('/content/Input2.png')

# %%
#from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
from matplotlib import image as mpimg

# %%
# 𝑠 = {10, 50, 100, 200} , the 4 test scenarios
import sys
from google.colab.patches import cv2_imshow
image1=cv2.imread('/content/Input1.png',cv2.IMREAD_COLOR)
image2=cv2.imread('/content/Input2.png',cv2.IMREAD_COLOR)




def mergeImages(image1, image2):
  s = {0.1, 0.5, 0.01, 0.02}
  for i in s :
    dest=cv2.addWeighted(image1 ,1.0,image2,i,0.0)
    test = cv2.imwrite('image_test'+str(i) +'.png' ,dest)

# %% [markdown]
# # Function 1

# %%
mergeImages(image1, image2)

# %% [markdown]
# ## The output of the 4 test Scenarios on Function 1

# %%
image_test_1 = plt.imread('/content/image_test0.1.png')
image_test_2 = plt.imread('/content/image_test0.5.png')
image_test_3 = plt.imread('/content/image_test0.01.png')
image_test_4 = plt.imread('/content/image_test0.02.png')


# create figure
fig = plt.figure(figsize=(10, 7))
fig.add_subplot(2, 2, 1)
# showing image
plt.imshow(image_test_1)
plt.title("s = 10")
# Adds a subplot at the 2nd position
fig.add_subplot(2, 2, 2)
# showing image
plt.imshow(image_test_2)
plt.title("s = 50")
# Adds a subplot at the 3rd position
fig.add_subplot(2, 2, 3)
# showing image
plt.imshow(image_test_3)
plt.title("s = 100")
# Adds a subplot at the 4th position
fig.add_subplot(2, 2, 4)
# showing image
plt.imshow(image_test_4)
plt.title("s = 200")
# Out:
# Text(0.5, 1.0, 's = 200')

# %% [markdown]
# # Function 2

# %%
image1=cv2.imread('/content/Input1.png',cv2.IMREAD_COLOR)
image2=cv2.imread('/content/Input2.png',cv2.IMREAD_COLOR)

def retrieveImage(image1, image2):
  s = {0.1, 0.5, 0.01, 0.02}
  for i in s :
    bfr_s =cv2.subtract(image1, image2)
    aftr_s = bfr_s * i
    test = cv2.imwrite('image_test_fun2_'+str(i) +'.png' ,aftr_s)

# %%
retrieveImage(image1, image2)

# %%
image_test_1 = plt.imread('/content/image_test_fun2_0.1.png')
image_test_2 = plt.imread('/content/image_test_fun2_0.5.png')
image_test_3 = plt.imread('/content/image_test_fun2_0.01.png')
image_test_4 = plt.imread('/content/image_test_fun2_0.02.png')


# create figure
fig = plt.figure(figsize=(10, 7))
fig.add_subplot(2, 2, 1)
# showing image
plt.imshow(image_test_1)
plt.title("s = 10")
# Adds a subplot at the 2nd position
fig.add_subplot(2, 2, 2)
# showing image
plt.imshow(image_test_2)
plt.title("s = 50")
# Adds a subplot at the 3rd position
fig.add_subplot(2, 2, 3)
# showing image
plt.imshow(image_test_3)
plt.title("s = 100")
# Adds a subplot at the 4th position
fig.add_subplot(2, 2, 4)
# showing image
plt.imshow(image_test_4)
plt.title("s = 200")
# Out:
# Text(0.5, 1.0, 's = 200')

# %% [markdown]
# #Function 3

# %% [markdown]
# # Function 4 XOR on gray scale images

# %%
gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

# %%
fig = plt.figure(figsize=(10, 7))
fig.add_subplot(1, 2, 1)
# showing image
plt.imshow(gray1)
plt.title("gray1")
# Adds a subplot at the 2nd position
fig.add_subplot(1, 2, 2)
# showing image
plt.imshow(gray2)
plt.title("gray2")
# Out:
# Text(0.5, 1.0, 'gray2')

# %%
def ImagesXOR(image1, image2):
  xor_img = cv2.bitwise_xor(image1,image2)
  test = cv2.imwrite('image_test_fun4.png' ,xor_img)

# %%
ImagesXOR(gray1, gray2)

# %%
image_test_1 = plt.imread('/content/image_test_fun2_0.1.png')
plt.imshow(image_test_1)
plt.title("image1 XOR image 2")
# Out:
# Text(0.5, 1.0, 'image1 XOR image 2')
